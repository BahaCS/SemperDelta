# %% [markdown]
# # 01 Job Scraper
# Optional notebook to demonstrate scraping or loading job postings.

# %%
from pathlib import Path
from src.scrape_jobs import load_jobs
df = load_jobs()
df.head()
