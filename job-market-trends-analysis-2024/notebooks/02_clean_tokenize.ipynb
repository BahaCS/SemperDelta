# %% [markdown]
# # 02 Clean & Tokenize

# %%
import pandas as pd
from src.scrape_jobs import load_jobs
from src.clean_jobs import clean_dataframe
df = load_jobs()
clean_df = clean_dataframe(df)
clean_df[['job_title','tokens']].head()
