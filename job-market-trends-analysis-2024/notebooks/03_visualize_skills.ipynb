# %% [markdown]
# # 03 Visualize Skills

# %%
from src.scrape_jobs import load_jobs
from src.clean_jobs import clean_dataframe
from src.visualize import plot_top_skills, generate_wordcloud
df = load_jobs()
clean_df = clean_dataframe(df)
plot_top_skills(clean_df['tokens'], save_path='../visuals/top_skills_bar.png')
generate_wordcloud(clean_df['tokens'], save_path='../visuals/skill_wordcloud.png')
