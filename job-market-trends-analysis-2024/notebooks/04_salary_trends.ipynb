# %% [markdown]
# # 04 Salary Trends

# %%
import pandas as pd
from src.scrape_jobs import load_jobs
df = load_jobs()
df['min_salary'] = df['salary'].str.extract('(\d+,\d+)').str.replace(',', '').astype(int)
df.groupby('experience_level')['min_salary'].mean()
